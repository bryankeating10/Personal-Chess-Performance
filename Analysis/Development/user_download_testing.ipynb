# %% [markdown]
# # **User game data download testing**

# %%
import sys
sys.path.append("../../")  # from Analysis/Development


from Utils import download_user

username = 'BKChessMaster2'
output_file = 'bk_data.pgn'
download_user(username,end="2023-01",output=output_file)
# Out:
# Fetching archives for: bkchessmaster2
# Filtering archives...
# Selected 1 archive(s):
#   → https://api.chess.com/pub/player/bkchessmaster2/games/2022/12
#
# Downloading 1 archives...
#  → Downloading https://api.chess.com/pub/player/bkchessmaster2/games/2022/12
#
# Saving PGN to C:\Users\Bryan Keating\BK-Laptop\Workshop\Analytics\Personal-Chess-Performance\Data\PGN\bk_data.pgn...
# Done.
# 'C:\\Users\\Bryan Keating\\BK-Laptop\\Workshop\\Analytics\\Personal-Chess-Performance\\Data\\PGN\\bk_data.pgn'
